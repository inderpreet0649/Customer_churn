# %% [markdown]
# # Importing liabraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading data

# %%
df = pd.read_csv("Data/Customer Churn.csv")

# %% [markdown]
# # Checking data structure

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5017  2073-QBVBI  Female              0     Yes         No      41
# 1136  6621-NRZAK  Female              0     Yes        Yes      63
# 6997  2523-EWWZL  Female              0     Yes         No      27
# 338   7982-VCELR  Female              0      No         No      36
# 907   0297-RBCSG    Male              0      No         No      19
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 5017           No  No phone service             DSL                   No  ...
# 1136          Yes                No              No  No internet service  ...
# 6997          Yes                No     Fiber optic                   No  ...
# 338           Yes                No     Fiber optic                   No  ...
# 907           Yes                No             DSL                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %% [markdown]
# # Checking columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # Making an backup

# %%
BACKUP = df.copy()

# %% [markdown]
# # Correcting the data type

# %%
df['TotalCharges'].astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['TotalCharges'].astype("float")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
df[df['TotalCharges'] == " "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# # Replacing banks with 0

# %%
df['TotalCharges'].replace(" ", "0", inplace=True)

# %%
df['TotalCharges'] =  df['TotalCharges'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
a = round(df['tenure'] * df['MonthlyCharges']) == round(df['TotalCharges'])

# %%
a.sum()
# Out:
# np.int64(684)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Checking null

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Co relation

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000

# %% [markdown]
# # Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Changing Senior citizen

# %%
def ZeroToNo(value):
    if value:
        return "Yes"
    else :
        return "No"

# %%
df['SeniorCitizen'] =  df['SeniorCitizen'].apply(ZeroToNo)

# %%
df
# Out:
#       customerID  gender SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            No     Yes         No       1
# 1     5575-GNVDE    Male            No      No         No      34
# 2     3668-QPYBK    Male            No      No         No       2
# 3     7795-CFOCW    Male            No      No         No      45
# 4     9237-HQITU  Female            No      No         No       2
# ...          ...     ...           ...     ...        ...     ...
# 7038  6840-RESVB    Male            No     Yes        Yes      24
# 7039  2234-XADUH  Female            No     Yes        Yes      72
# 7040  4801-JZAZL  Female            No     Yes        Yes      11
# 7041  8361-LTMKD    Male           Yes     Yes         No       4
# 7042  3186-AJIEK    Male            No      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Customer count by churn

# %%
plt.figure(figsize=(4,4))
ax = sns.countplot(x="Churn", data= df)
ax.bar_label(ax.containers[0])
plt.title("Customer Count by Churn", fontdict={"fontsize":10, 'font': 'Bell MT'})
plt.show()

# %%
gb = df.groupby("Churn").agg({"Churn": "count"})
gb
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
plt.figure(figsize=(3,3))
plt.pie(gb['Churn'], labels= gb.index, autopct='%1.1f%%')
plt.title("Percentage of Churened Customers", fontdict={"fontsize":10, 'font': 'Bell MT'})
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4,4))
ax = sns.countplot(x="SeniorCitizen", data= df, hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Customer Count by Churn", fontdict={"fontsize":10, 'font': 'Bell MT'})
plt.show()

# %%
import matplotlib.pyplot as plt

# Step 1: Create a crosstab (counts by SeniorCitizen and Churn)
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'])

# Step 2: Plot a stacked bar chart
ct.plot(kind='bar', stacked=True, figsize=(4, 4), color=['skyblue', 'salmon'])

# Step 3: Customize the plot
plt.title('Customer Count by Churn (Stacked)', fontsize=10, fontname='Bell MT')  # Optional: fontname
plt.xlabel('Senior Citizen')
plt.ylabel('Customer Count')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)  # Optional: rename 0/1 to No/Yes
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Step 1: Create a crosstab (counts)
ct = pd.crosstab(df['SeniorCitizen'], df['Churn'])

# Step 2: Convert counts to row-wise percentages
ct_percent = ct.div(ct.sum(axis=1), axis=0) * 100

# Step 3: Plot
ax = ct_percent.plot(kind='bar', stacked=True, figsize=(4, 4), color=['skyblue', 'salmon'])

# Step 4: Add percentage labels
for i, row in enumerate(ct_percent.values):
    cumulative = 0
    for j, val in enumerate(row):
        if val > 0:
            ax.text(
                i,
                cumulative + val / 2,
                f'{val:.1f}%',
                ha='center',
                va='center',
                fontsize=8,
                color='black'
            )
            cumulative += val

# Step 5: Customize plot
plt.title('Customer Churn Rate by Senior Citizen Status', fontsize=10, fontname='Bell MT')  # Optional: custom font
plt.xlabel('Senior Citizen')
plt.ylabel('Percentage')
plt.xticks(ticks=[0, 1], labels=['No', 'Yes'], rotation=0)
plt.ylim(0, 100)
plt.legend(title='Churn')
plt.tight_layout()
plt.show()

# %%
sns.countplot(x='Contract',data=df , hue='Churn')
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
ax =sns.countplot(x='Contract',data=df , hue='Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Count of customers by contract")
plt.show()

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
columns = ['PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
axes.reshape(-1)
# Out:
# array([<Axes: title={'center': 'Count Plot of SeniorCitizen'}, xlabel='SeniorCitizen', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of Partner'}, xlabel='Partner', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of Dependents'}, xlabel='Dependents', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of PhoneService'}, xlabel='PhoneService', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of MultipleLines'}, xlabel='MultipleLines', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of InternetService'}, xlabel='InternetService', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of OnlineSecurity'}, xlabel='OnlineSecurity', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of OnlineBackup'}, xlabel='OnlineBackup', ylabel='count'>,
#        <Axes: title={'center': 'Count Plot of DeviceProtection'}, xlabel='DeviceProtection', ylabel='count'>,
# ...

# %%
n_col = 3
n_rows = 3

fig , axes = plt.subplots(n_rows,n_col , figsize =(15,15))
axes = axes.flatten()

for i in range(len(columns)):
    print(i,columns[i])
    sns.countplot(data = df,x=columns[i] , hue = df['Churn'], ax=axes[i])
    axes[i].set_title(f'count plot of {columns[i]}')
# Out:
# 0 PhoneService
# 1 MultipleLines
# 2 InternetService
# 3 OnlineSecurity
# 4 OnlineBackup
# 5 DeviceProtection
# 6 TechSupport
# 7 StreamingTV
# 8 StreamingMovies

# %%
n_col = 3
n_rows = 3

fig , axes = plt.subplots(n_rows,n_col , figsize =(15,15))
axes = axes.flatten()

for i in range(len(columns)):
    #print(i,columns[i])
    sns.countplot(data = df,x=columns[i] , hue = df['Churn'], ax=axes[i])
    axes[i].set_title(f'count plot of {columns[i]}')
# always use tightlayout for better cleaning or showing of graphs
plt.tight_layout()

# %%
columns = ['SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']

# %%
len(columns)
# Out:
# 16

# %%
n_col = 4
n_rows = 4

fig , axes = plt.subplots(n_rows,n_col , figsize =(15,15))
axes = axes.flatten()

for i in range(len(columns)):
    #print(i,columns[i])
    sns.countplot(data = df,x=columns[i] , hue = df['Churn'], ax=axes[i])
    axes[i].set_title(f'count plot of {columns[i]}')
# always use tightlayout for better cleaning or showing of graphs
plt.tight_layout()

# %%
columns = ['SeniorCitizen', 'Partner', 'Dependents',
       'gender', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']

# %%
n_col = 4
n_rows = 4

fig , axes = plt.subplots(n_rows,n_col , figsize =(15,15))
axes = axes.flatten()

for i in range(len(columns)):
    #print(i,columns[i])
    sns.countplot(data = df,x=columns[i] , hue = df['Churn'], ax=axes[i])
    axes[i].set_title(f'count plot of {columns[i]}')
# always use tightlayout for better cleaning or showing of graphs
plt.tight_layout()

# %%
columns = ['SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
       'PaperlessBilling', 'PaymentMethod']

# %%
n_col = 3
n_rows = 5

fig , axes = plt.subplots(n_rows,n_col , figsize =(15,15))
axes = axes.flatten()

for i in range(len(columns)):
    #print(i,columns[i])
    sns.countplot(data = df,x=columns[i] , hue = df['Churn'], ax=axes[i])
    axes[i].set_title(f'count plot of {columns[i]}')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
# always use tightlayout for better cleaning or showing of graphs
plt.tight_layout()

# %%
n_col = 3
n_rows = 5

fig, axes = plt.subplots(n_rows, n_col, figsize=(16, 16))
axes = axes.flatten()

for i in range(len(columns)):
    ax = sns.countplot(data=df, x=columns[i], hue='Churn', ax=axes[i])
    axes[i].set_title(f'Count Plot of {columns[i]}')

    # Get total count per group for percentage calculation
    total_per_category = df[columns[i]].value_counts()

    for container in ax.containers:
        # Compute total count for each bar group (hue value)
        labels = []
        for bar in container:
            height = bar.get_height()
            x_val = bar.get_x() + bar.get_width() / 2
            x_category = round(x_val)  # approximate index for x-axis category
            
            # Get category name from bar's x position
            category_idx = int(bar.get_x() + bar.get_width() / 2)
            category_name = bar.get_x()
            
            # Get corresponding x-tick label (safer way)
            xtick_labels = [tick.get_text() for tick in ax.get_xticklabels()]
            if xtick_labels:
                category_name = xtick_labels[container.index(bar) % len(xtick_labels)]

            # Compute percentage
            total = df[df[columns[i]] == category_name].shape[0]
            percent = (height / total) * 100 if total > 0 else 0
            labels.append(f'{percent:.1f}%')

        ax.bar_label(container, labels=labels)
plt.tight_layout()

# %% [markdown]
# # Key Insights
#
# #### SeniorCitizen
# - 23.6% of senior citizens churned, higher than the 16.4% of non-seniors, indicating potential dissatisfaction among older customers.
#
# #### Partner
# - 19.7% of customers with partners churned, compared to a lower rate among those without, suggesting relationship status may influence retention.
#
# #### Dependents
# - 15.5% of customers with dependents churned, less than those without (31.3%), indicating dependents might stabilize customer loyalty.
#
# #### PhoneService
# - 26.7% of customers without phone service churned, slightly more than the 24.9% with it, pointing to limited service uptake as a factor.
#
# #### MultipleLines
# - 28.6% of customers with multiple lines churned, higher than the 24.9% without, suggesting complexity may lead to dissatisfaction.
#
# #### InternetService
# - Fiber optic users show a 19.0% churn rate, significantly higher than DSL’s 7.4%, highlighting potential service quality issues.
#
# #### OnlineSecurity
# - 14.6% churn without online security versus 7.4% with it, indicating security concerns drive customer departures.
#
# #### OnlineBackup
# - 7.4% churn without online backup (no internet service) versus higher rates with it, suggesting backup may not be a key retention factor.
#
# #### DeviceProtection
# - 7.4% churn without device protection (no internet service) versus higher rates with it, indicating limited impact on retention.
#
# #### TechSupport
# - 15.2% churn without tech support versus 7.4% with it, showing the importance of support services.
#
# #### StreamingTV
# - 7.4% churn without streaming TV (no internet service) versus higher rates with it, suggesting limited retention value.
#
# #### StreamingMovies
# - 7.4% churn without streaming movies (no internet service) versus higher rates with it, indicating minimal impact on churn.
#
# #### Contract
# - 42.7% churn with month-to-month contracts compared to 2.8% with two-year contracts, emphasizing the role of contract duration.
#
# #### PaperlessBilling
# - 16.3% churn without paperless billing versus 33.6% with it, suggesting billing preferences affect retention.
#
# #### PaymentMethod
# - 19.1% churn with electronic checks versus 15.2% with bank transfers, indicating payment method influences churn rates.

# %% [markdown]
# # Conclusion
# Customer churn is significantly influenced by contract duration, with month-to-month users leaving at the highest rate. The absence of additional services like online security and variations in internet service quality (e.g., fiber optic vs. DSL) also contribute to higher churn. Demographic factors, such as senior citizens, and lack of phone service further exacerbate the issue.
#
# # Suggestions
#
# Offer incentives for longer contracts to reduce month-to-month churn.
# Promote additional services like online security and tech support to enhance customer retention.
# Improve fiber optic service quality to match DSL satisfaction levels.
# Provide tailored support for senior citizens to address their specific needs.
# Encourage adoption of phone services to increase customer engagement.
